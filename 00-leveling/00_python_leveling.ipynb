# %%
import math
from dataclasses import dataclass

# ===== Scoring helpers =====
@dataclass
class TaskResult:
    passed: bool
    points_awarded: int
    points_max: int
    message: str

_RESULTS = {}

def _ok(task: str, pts: int, pts_max: int, msg: str = "OK"):
    _RESULTS[task] = TaskResult(True, pts, pts_max, msg)

def _fail(task: str, pts_max: int, msg: str):
    _RESULTS[task] = TaskResult(False, 0, pts_max, msg)

def _require(cond: bool, msg: str):
    if not cond:
        raise AssertionError(msg)

def summary():
    total = sum(r.points_awarded for r in _RESULTS.values())
    total_max = sum(r.points_max for r in _RESULTS.values())
    print("=== SCORE SUMMARY (Python-only) ===")
    for k, r in _RESULTS.items():
        status = "PASS" if r.passed else "FAIL"
        print(f"{k:>6} | {status:4} | {r.points_awarded:3}/{r.points_max:3} | {r.message}")
    print(f"\nTOTAL: {total}/{total_max}")

    # Proponowana interpretacja
    if total < 20:
        print("DIAGNOZA: P0.")
    elif total < 40:
        print("DIAGNOZA: P1.")
    elif total < 60:
        print("DIAGNOZA: P2.")
    else:
        print("DIAGNOZA: P3.")

# %%
# A1 (10 pts)
scores = [2, 4, 4, 4, 5, 5, 7, 9]

# TODO:
# - oblicz mean (średnia)
# - oblicz variance_pop (wariancja populacyjna, dzielisz przez N)
# Podpowiedź: variance = sum((x-mean)^2)/N

mean = None
variance_pop = None

# %%
def test_A1():
    task, pts = "A1", 10
    try:
        _require(isinstance(mean, (int, float)), "mean powinno być liczbą")
        _require(isinstance(variance_pop, (int, float)), "variance_pop powinno być liczbą")
        _require(abs(mean - 5.0) < 1e-9, "zła średnia")
        _require(abs(variance_pop - 4.0) < 1e-9, "zła wariancja populacyjna")
        _ok(task, pts, pts)
    except Exception as e:
        _fail(task, pts, str(e))

test_A1()
summary()
# Out:
# === SCORE SUMMARY (Python-only) ===
#     A1 | FAIL |   0/ 10 | mean powinno być liczbą
#
# TOTAL: 0/10
# DIAGNOZA: P0.

# %%
# A2 (10 pts)
text = "  Hello,   WORLD!!!  "

# TODO:
# - zamień na lowercase
# - usuń przecinki i wykrzykniki (zamień je na spację)
# - zredukuj wielokrotne spacje do jednej
# - obetnij spacje z początku/końca
# Wynik ma być dokładnie: "hello world"

clean = None

# %%
def test_A2():
    task, pts = "A2", 10
    try:
        _require(clean == "hello world", f"clean powinno być 'hello world', a jest: {clean!r}")
        _ok(task, pts, pts)
    except Exception as e:
        _fail(task, pts, str(e))

test_A2()
summary()
# Out:
# === SCORE SUMMARY (Python-only) ===
#     A1 | FAIL |   0/ 10 | mean powinno być liczbą
#     A2 | FAIL |   0/ 10 | clean powinno być 'hello world', a jest: None
#
# TOTAL: 0/20
# DIAGNOZA: P0.

# %%
# A3 (10 pts)
nums = [10, 3, 7, 7, 2, 9, 1, 9, 4]

# TODO:
# - wybierz tylko liczby >= 5
# - posortuj malejąco
# - weź top3
# Wynik ma być listą: [10, 9, 9]

top3 = None

# %%
def test_A3():
    task, pts = "A3", 10
    try:
        _require(top3 == [10, 9, 9], f"top3 powinno być [10, 9, 9], a jest: {top3!r}")
        _ok(task, pts, pts)
    except Exception as e:
        _fail(task, pts, str(e))

test_A3()
summary()
# Out:
# === SCORE SUMMARY (Python-only) ===
#     A1 | FAIL |   0/ 10 | mean powinno być liczbą
#     A2 | FAIL |   0/ 10 | clean powinno być 'hello world', a jest: None
#     A3 | FAIL |   0/ 10 | top3 powinno być [10, 9, 9], a jest: None
#
# TOTAL: 0/30
# DIAGNOZA: P0.

# %%
# A4 (15 pts)
labels = ["cat","dog","cat","mouse","dog","cat","dog","dog"]

# TODO:
# - zbuduj słownik counts, np. {"cat": 3, "dog": 4, "mouse": 1}
# - bez collections.Counter (chcemy zobaczyć pętle + dict)

counts = None

# %%
def test_A4():
    task, pts = "A4", 15
    try:
        _require(isinstance(counts, dict), "counts powinno być dictem")
        _require(counts.get("cat") == 3, "zła liczność cat")
        _require(counts.get("dog") == 4, "zła liczność dog")
        _require(counts.get("mouse") == 1, "zła liczność mouse")
        _ok(task, pts, pts)
    except Exception as e:
        _fail(task, pts, str(e))

test_A4()
summary()
# Out:
# === SCORE SUMMARY (Python-only) ===
#     A1 | FAIL |   0/ 10 | mean powinno być liczbą
#     A2 | FAIL |   0/ 10 | clean powinno być 'hello world', a jest: None
#     A3 | FAIL |   0/ 10 | top3 powinno być [10, 9, 9], a jest: None
#     A4 | FAIL |   0/ 15 | counts powinno być dictem
#
# TOTAL: 0/45
# DIAGNOZA: P0.

# %%
# A5 (5 pts)
score = 73

# TODO:
# Ustaw grade:
# - >= 90: "A"
# - >= 80: "B"
# - >= 70: "C"
# - >= 60: "D"
# - inaczej: "F"
grade = None

# %%
def test_A5():
    task, pts = "A5", 5
    try:
        _require(grade == "C", f"grade powinno być 'C', a jest {grade!r}")
        _ok(task, pts, pts)
    except Exception as e:
        _fail(task, pts, str(e))

test_A5()
summary()
# Out:
# === SCORE SUMMARY (Python-only) ===
#     A1 | FAIL |   0/ 10 | mean powinno być liczbą
#     A2 | FAIL |   0/ 10 | clean powinno być 'hello world', a jest: None
#     A3 | FAIL |   0/ 10 | top3 powinno być [10, 9, 9], a jest: None
#     A4 | FAIL |   0/ 15 | counts powinno być dictem
#     A5 | FAIL |   0/  5 | grade powinno być 'C', a jest None
#
# TOTAL: 0/50
# DIAGNOZA: P0.

# %%
# A6 (10 pts)
csv_text = """name,age
Ala,20
Ola,22
Jan,19
"""

# TODO:
# - sparsuj csv_text (bez pandas!)
# - wynik: people = [{"name":"Ala","age":20}, ...]
# - age ma być int

people = None

# %%
def test_A6():
    task, pts = "A6", 10
    try:
        _require(isinstance(people, list), "people powinno być listą")
        _require(len(people) == 3, "people ma mieć 3 rekordy")
        _require(people[0] == {"name":"Ala","age":20}, f"pierwszy rekord zły: {people[0]!r}")
        _require(all(isinstance(p["age"], int) for p in people), "age musi być int")
        _ok(task, pts, pts)
    except Exception as e:
        _fail(task, pts, str(e))

test_A6()
summary()
# Out:
# === SCORE SUMMARY (Python-only) ===
#     A1 | FAIL |   0/ 10 | mean powinno być liczbą
#     A2 | FAIL |   0/ 10 | clean powinno być 'hello world', a jest: None
#     A3 | FAIL |   0/ 10 | top3 powinno być [10, 9, 9], a jest: None
#     A4 | FAIL |   0/ 15 | counts powinno być dictem
#     A5 | FAIL |   0/  5 | grade powinno być 'C', a jest None
#     A6 | FAIL |   0/ 10 | people powinno być listą
#
# TOTAL: 0/60
# DIAGNOZA: P0.

# %%
# B1 (15 pts)
def safe_div(a, b):
    """
    TODO:
    - jeśli b == 0: zwróć None
    - inaczej: zwróć a/b
    """
    pass

# %%
def test_B1():
    task, pts = "B1", 15
    try:
        _require(safe_div(10, 2) == 5, "10/2 powinno dać 5")
        _require(safe_div(10, 0) is None, "dzielenie przez 0 powinno dać None")
        _ok(task, pts, pts)
    except Exception as e:
        _fail(task, pts, str(e))

test_B1()
summary()
# Out:
# === SCORE SUMMARY (Python-only) ===
#     A1 | FAIL |   0/ 10 | mean powinno być liczbą
#     A2 | FAIL |   0/ 10 | clean powinno być 'hello world', a jest: None
#     A3 | FAIL |   0/ 10 | top3 powinno być [10, 9, 9], a jest: None
#     A4 | FAIL |   0/ 15 | counts powinno być dictem
#     A5 | FAIL |   0/  5 | grade powinno być 'C', a jest None
#     A6 | FAIL |   0/ 10 | people powinno być listą
#     B1 | FAIL |   0/ 15 | 10/2 powinno dać 5
#
# TOTAL: 0/75
# DIAGNOZA: P0.

# %%
# B2 (25 pts)
def is_palindrome(s: str) -> bool:
    """
    TODO:
    - zignoruj spacje
    - zignoruj wielkość liter
    - zwróć True jeśli po czyszczeniu tekst czytany od tyłu jest taki sam
    """
    pass

# %%
def test_B2():
    task, pts = "B2", 25
    try:
        _require(is_palindrome("Ala") is False, "Ala nie jest palindromem")
        _require(is_palindrome("Kobyla ma maly bok") is True, "to powinno być True")
        _require(is_palindrome("Never odd or even") is True, "to powinno być True")
        _ok(task, pts, pts)
    except Exception as e:
        _fail(task, pts, str(e))

test_B2()
summary()
# Out:
# === SCORE SUMMARY (Python-only) ===
#     A1 | FAIL |   0/ 10 | mean powinno być liczbą
#     A2 | FAIL |   0/ 10 | clean powinno być 'hello world', a jest: None
#     A3 | FAIL |   0/ 10 | top3 powinno być [10, 9, 9], a jest: None
#     A4 | FAIL |   0/ 15 | counts powinno być dictem
#     A5 | FAIL |   0/  5 | grade powinno być 'C', a jest None
#     A6 | FAIL |   0/ 10 | people powinno być listą
#     B1 | FAIL |   0/ 15 | 10/2 powinno dać 5
#     B2 | FAIL |   0/ 25 | Ala nie jest palindromem
#
# TOTAL: 0/100
# DIAGNOZA: P0.

# %%
def run_all_tests():
    _RESULTS.clear()
    test_A1()
    test_A2()
    test_A3()
    test_A4()
    test_A5()
    test_A6()
    # B jest opcjonalne, ale jak ktoś zrobi — liczy się do sumy
    try:
        test_B1()
    except:
        pass
    try:
        test_B2()
    except:
        pass
    summary()

run_all_tests()
# Out:
# === SCORE SUMMARY (Python-only) ===
#     A1 | FAIL |   0/ 10 | mean powinno być liczbą
#     A2 | FAIL |   0/ 10 | clean powinno być 'hello world', a jest: None
#     A3 | FAIL |   0/ 10 | top3 powinno być [10, 9, 9], a jest: None
#     A4 | FAIL |   0/ 15 | counts powinno być dictem
#     A5 | FAIL |   0/  5 | grade powinno być 'C', a jest None
#     A6 | FAIL |   0/ 10 | people powinno być listą
#     B1 | FAIL |   0/ 15 | 10/2 powinno dać 5
#     B2 | FAIL |   0/ 25 | Ala nie jest palindromem
#
# TOTAL: 0/100
# DIAGNOZA: P0.
