# %%
# TODO: napisz funkcję safe_float(s)
# Funkcja ma:
# - zwrócić float(s), jeśli konwersja się uda
# - zwrócić None, jeśli się nie uda

def safe_float(s):
    pass

try:
    assert safe_float("3.14") == 3.14
    assert safe_float("10") == 10.0
    assert safe_float("abc") is None
    print("OK ✅")
except Exception as e:
    print("Błąd:", e)
# Out:
# Błąd:

# %%
line = "Ala,20,4.5"

# Oczekiwany wynik:
# {"name": "Ala", "age": 20, "score": 4.5}

# TODO: napisz funkcję parse_student(line)
# Wskazówka:
# - rozbij line po przecinku
# - age zamień na int
# - score zamień na float

def parse_student(line):
    pass

try:
    assert parse_student("Ala,20,4.5") == {"name": "Ala", "age": 20, "score": 4.5}
    assert parse_student("Jan,19,3.0") == {"name": "Jan", "age": 19, "score": 3.0}
    print("OK ✅")
except Exception as e:
    print("Błąd:", e)
# Out:
# Błąd:

# %%
csv_text = """name,age,score
Ala,20,4.5
Jan,19,3.0
Ola,21,5.0
"""

# TODO: napisz funkcję load_students(csv_text)
# Funkcja ma:
# - podzielić tekst na linie
# - pominąć nagłówek
# - pominąć puste linie
# - użyć funkcji parse_student(line)
# - zwrócić listę słowników

def parse_student(line):
    name, age, score = line.split(",")
    return {
        "name": name,
        "age": int(age),
        "score": float(score)
    }

def load_students(csv_text):
    pass

try:
    result = load_students(csv_text)
    assert result == [
        {"name": "Ala", "age": 20, "score": 4.5},
        {"name": "Jan", "age": 19, "score": 3.0},
        {"name": "Ola", "age": 21, "score": 5.0}
    ]
    print("OK ✅")
except Exception as e:
    print("Błąd:", e)
# Out:
# Błąd:

# %%
students = [
    {"name": "Ala", "age": 20, "score": 4.5},
    {"name": "Jan", "age": 19, "score": 3.0},
    {"name": "Ola", "age": 21, "score": 5.0}
]

# TODO: napisz funkcję get_column(data, key)
# Funkcja ma zwrócić listę wartości z podanego klucza

def get_column(data, key):
    pass

try:
    assert get_column(students, "name") == ["Ala", "Jan", "Ola"]
    assert get_column(students, "score") == [4.5, 3.0, 5.0]
    print("OK ✅")
except Exception as e:
    print("Błąd:", e)
# Out:
# Błąd:

# %%
scores = [4.5, 3.0, 5.0]

# TODO: napisz funkcję mean(values)
# Funkcja ma:
# - policzyć sumę elementów
# - zwrócić średnią arytmetyczną

def mean(values):
    pass

try:
    assert mean([2, 4, 6]) == 4.0
    assert mean([5]) == 5.0
    print("OK ✅")
except Exception as e:
    print("Błąd:", e)
# Out:
# Błąd:

# %%
scores = [2.0, 3.0, 5.0]

# TODO: napisz funkcję min_max_scale(values)
# Wzór:
# (x - min_value) / (max_value - min_value)
#
# Funkcja ma zwrócić nową listę z wartościami po skalowaniu do zakresu [0, 1]

def min_max_scale(values):
    pass

try:
    result = min_max_scale([2.0, 3.0, 5.0])
    assert result == [0.0, 1/3, 1.0]
    print("OK ✅")
except Exception as e:
    print("Błąd:", e)
# Out:
# Błąd:

# %%
students = [
    {"name": "Ala", "hours": 10, "projects": 2},
    {"name": "Jan", "hours": 4, "projects": 1},
    {"name": "Ola", "hours": 12, "projects": 3}
]

# TODO: napisz funkcję add_activity_score(student)
# Nowa cecha ma być liczona jako:
# activity_score = hours + 2 * projects
#
# Funkcja ma zwrócić NOWY słownik, rozszerzony o klucz "activity_score"

def add_activity_score(student):
    pass

try:
    assert add_activity_score({"name": "Ala", "hours": 10, "projects": 2}) == {
        "name": "Ala",
        "hours": 10,
        "projects": 2,
        "activity_score": 14
    }
    print("OK ✅")
except Exception as e:
    print("Błąd:", e)
# Out:
# Błąd:

# %%
students = [
    {"name": "Ala", "hours": 10, "projects": 2},
    {"name": "Jan", "hours": 4, "projects": 1},
    {"name": "Ola", "hours": 12, "projects": 3}
]

def add_activity_score(student):
    return {
        "name": student["name"],
        "hours": student["hours"],
        "projects": student["projects"],
        "activity_score": student["hours"] + 2 * student["projects"]
    }

# TODO: napisz funkcję transform_students(data)
# Funkcja ma:
# - przejść po wszystkich studentach
# - dla każdego wywołać add_activity_score
# - zwrócić nową listę

def transform_students(data):
    pass

try:
    result = transform_students(students)
    assert result[0]["activity_score"] == 14
    assert result[1]["activity_score"] == 6
    assert result[2]["activity_score"] == 18
    print("OK ✅")
except Exception as e:
    print("Błąd:", e)
# Out:
# Błąd: 'NoneType' object is not subscriptable

# %%
student = {"name": "Ala", "hours": 10, "projects": 2}

# TODO: napisz funkcję predict_pass(student)
# Reguła:
# - jeśli hours >= 8 i projects >= 2 -> zwróć 1
# - w przeciwnym razie zwróć 0

def predict_pass(student):
    pass

try:
    assert predict_pass({"name": "Ala", "hours": 10, "projects": 2}) == 1
    assert predict_pass({"name": "Jan", "hours": 4, "projects": 1}) == 0
    print("OK ✅")
except Exception as e:
    print("Błąd:", e)
# Out:
# Błąd:

# %%
y_true = [1, 0, 1, 1, 0]
y_pred = [1, 0, 0, 1, 0]

# TODO: napisz funkcję accuracy(y_true, y_pred)
# accuracy = liczba poprawnych predykcji / liczba wszystkich predykcji

def accuracy(y_true, y_pred):
    pass

try:
    assert accuracy([1, 0, 1], [1, 0, 0]) == 2/3
    assert accuracy([1, 1], [1, 1]) == 1.0
    print("OK ✅")
except Exception as e:
    print("Błąd:", e)
# Out:
# Błąd:

# %%
csv_text = """name,hours,projects,passed
Ala,10,2,1
Jan,4,1,0
Ola,12,3,1
Piotr,6,1,0
Kasia,8,2,1
"""

# TODO 1: napisz funkcję parse_row(line), która zwraca słownik:
# {"name": ..., "hours": ..., "projects": ..., "passed": ...}

def parse_row(line):
    pass

# TODO 2: napisz funkcję load_data(csv_text),
# która zwraca listę słowników

def load_data(csv_text):
    pass

# TODO 3: napisz funkcję add_activity_score(student),
# gdzie:
# activity_score = hours + 2 * projects

def add_activity_score(student):
    pass

# TODO 4: napisz funkcję transform_data(data),
# która dodaje activity_score do każdego rekordu

def transform_data(data):
    pass

# TODO 5: napisz funkcję predict_pass(student),
# reguła:
# jeśli activity_score >= 12 -> 1
# w przeciwnym razie -> 0

def predict_pass(student):
    pass

# TODO 6: napisz funkcję predict_all(data),
# która zwraca listę predykcji

def predict_all(data):
    pass

# TODO 7: napisz funkcję get_labels(data),
# która zwraca listę prawdziwych etykiet "passed"

def get_labels(data):
    pass

# TODO 8: napisz funkcję accuracy(y_true, y_pred)

def accuracy(y_true, y_pred):
    pass


data = load_data(csv_text)
data = transform_data(data)

y_true = get_labels(data)
y_pred = predict_all(data)

print("Dane:", data)
print("y_true:", y_true)
print("y_pred:", y_pred)
print("accuracy:", accuracy(y_true, y_pred))
# Out:
# Dane: None
# y_true: None
# y_pred: None
# accuracy: None
