# %% [markdown]
# # NumPy pod dane: losowanie, reshape, łączenie tablic i copy/view
#
# ## Cele
# - tworzenie losowych danych w NumPy
# - lepsze rozumienie reshape
# - łączenie tablic w większe struktury
# - zrozumienie różnicy między view i copy
# - przygotowanie danych w stylu „X i y” pod ML
