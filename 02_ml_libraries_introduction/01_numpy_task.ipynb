# %%
import numpy as np

names = np.array(["Ala", "Ola", "Jan", "Piotr", "Kasia"])

scores = np.array([
    [4, 5, 4],
    [5, 5, 5],
    [3, 4, 3],
    [5, 4, 4],
    [2, 3, 2]
])

# TODO: pobierz kształt tablicy scores
shape = None

# TODO: pobierz oceny z pierwszego przedmiotu (pierwsza kolumna)
first_subject = None

# TODO: policz średnią wszystkich ocen
mean_all = None

# TODO: policz średnią dla każdego studenta (po wierszach)
mean_per_student = None

# TODO: policz średnią dla każdego przedmiotu (po kolumnach)
mean_per_subject = None

# TODO: utwórz maskę dla ocen >= 4
mask_ge4 = None

# TODO: wybierz wszystkie oceny >= 4
good_scores = None

# TODO: policz liczbę ocen >= 4
count_ge4 = None

# TODO: policz rozstęp ocen
score_range = None

# TODO: policz procent ocen >= 4
share_ge4 = None

# TODO: utwórz maskę studentów ze średnią >= 4.0
good_students_mask = None

# TODO: wybierz imiona studentów ze średnią >= 4.0
good_students = None

# TODO: utwórz maskę studentów ze średnią >= 4.5
top_students_mask = None

# TODO: wybierz imiona studentów ze średnią >= 4.5
top_students = None

# TODO: spłaszcz tablicę scores do jednego wymiaru
flat_scores = None

print("Kształt:", shape)
print("Oceny z 1. przedmiotu:", first_subject)
print("Średnia wszystkich ocen:", mean_all)
print("Średnia per student:", mean_per_student)
print("Średnia per subject:", mean_per_subject)
print("Oceny >= 4:", good_scores)
print("Liczba ocen >= 4:", count_ge4)
print("Rozstęp ocen:", score_range)
print("Procent ocen >= 4:", share_ge4)
print("Studenci ze średnią >= 4.0:", good_students)
print("Studenci ze średnią >= 4.5:", top_students)
print("Spłaszczone oceny:", flat_scores)
try:
    assert shape == (5, 3)
    assert np.array_equal(first_subject, np.array([4, 5, 3, 5, 2]))

    assert abs(mean_all - (58 / 15)) < 1e-9
    assert np.allclose(mean_per_student, np.array([13 / 3, 5.0, 10 / 3, 13 / 3, 7 / 3]))
    assert np.allclose(mean_per_subject, np.array([3.8, 4.2, 3.6]))

    assert np.array_equal(
        mask_ge4,
        np.array([
            [True, True, True],
            [True, True, True],
            [False, True, False],
            [True, True, True],
            [False, False, False]
        ])
    )

    assert np.array_equal(good_scores, np.array([4, 5, 4, 5, 5, 5, 4, 5, 4, 4]))
    assert count_ge4 == 10
    assert score_range == 3
    assert abs(share_ge4 - (10 / 15) * 100) < 1e-9

    assert np.array_equal(good_students_mask, np.array([True, True, False, True, False]))
    assert np.array_equal(good_students, np.array(["Ala", "Ola", "Piotr"]))

    assert np.array_equal(top_students_mask, np.array([False, True, False, False, False]))
    assert np.array_equal(top_students, np.array(["Ola"]))

    assert np.array_equal(flat_scores, np.array([4, 5, 4, 5, 5, 5, 3, 4, 3, 5, 4, 4, 2, 3, 2]))

    print("OK ✅")
except NameError as e:
    print("Brakuje zmiennej:", e)
except Exception as e:
    print("Błąd:", e)
# Out:
# Kształt: None
# Oceny z 1. przedmiotu: None
# Średnia wszystkich ocen: None
# Średnia per student: None
# Średnia per subject: None
# Oceny >= 4: None
# Liczba ocen >= 4: None
# Rozstęp ocen: None
# Procent ocen >= 4: None
# Studenci ze średnią >= 4.0: None
# Studenci ze średnią >= 4.5: None
# Spłaszczone oceny: None
# Błąd:
