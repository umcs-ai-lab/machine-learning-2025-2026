# %% [markdown]
# # Zadanie: pierwsze kroki z Pandas — analiza stanów magazynowych
#
# ## Cel
# Ćwiczenie ma pomóc w:
# - wczytywaniu danych CSV do `DataFrame`
# - sprawdzaniu struktury danych
# - wybieraniu kolumn i wierszy
# - filtrowaniu rekordów
# - tworzeniu nowych kolumn
# - obsłudze brakujących danych
# - zapisywaniu wyników do pliku
#
# ## Polecenie
# Pracujesz z prostą tabelą magazynową zawierającą informacje o produktach:
# - identyfikator
# - dział
# - nazwa produktu
# - cena
# - liczba sztuk
#
# Twoim zadaniem jest:
# 1. utworzyć lub wczytać plik `mini_inventory.csv`,
# 2. wyświetlić podstawowe informacje o danych,
# 3. wykonać kilka przykładów selekcji i filtrowania,
# 4. dodać nową kolumnę z wartością zapasu,
# 5. zasymulować brak danych i go uzupełnić,
# 6. zapisać wynik do nowego pliku CSV.

# %%
data_dir = Path(".")
csv_path = data_dir / "mini_inventory.csv"

if not csv_path.exists():
    csv_text = (
        "id,department,product,price,stock\n"
        "1,office,Notebook,12.50,20\n"
        "2,office,Pen Set,8.90,35\n"
        "3,electronics,Keyboard,99.00,5\n"
        "4,electronics,Monitor,799.00,2\n"
        "5,kitchen,Mug,18.00,12\n"
        "6,kitchen,Plate Set,45.00,6\n"
        "7,office,Stapler,22.00,8\n"
        "8,electronics,Webcam,149.00,4\n"
    )
    csv_path.write_text(csv_text, encoding="utf-8")

print("Plik gotowy:", csv_path.resolve())
